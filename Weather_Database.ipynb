# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
#generate random coordinates of size 2000
lats = np.random.uniform(low=-90.000, high = 90.000, size = 2000)
longs = np.random.uniform(low=-180.000, high = 180.000, size = 2000)
lat_longs = zip(lats, longs)
lat_longs

# %%
coordinates = list(lat_longs)

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 767

# %%
first_city = cities[0]

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
first_city_url = url + "&q=" + first_city
first_city_weather = requests.get(first_city_url).json()
first_city_weather
# Out:
# {'coord': {'lon': -16.3333, 'lat': 33.0833},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 69.22,
#   'feels_like': 69.51,
#   'temp_min': 69.22,
#   'temp_max': 71.53,
#   'pressure': 1020,
#   'humidity': 78},
#  'visibility': 10000,
#  'wind': {'speed': 11.5, 'deg': 20},
#  'clouds': {'all': 75},
#  'dt': 1627337988,
#  'sys': {'type': 1,
#   'id': 6902,
#   'country': 'PT',
#   'sunrise': 1627280064,
#   'sunset': 1627330142},
#  'timezone': 3600,
#  'id': 2270385,
#  'name': 'Camacha',
#  'cod': 200}

# %%
first_city_descr = first_city_weather["weather"][0]["description"]
first_city_descr
# Out:
# 'broken clouds'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in our list.

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_descr = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_descr,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | camacha
# Processing Record 2 of Set 1 | faanui
# Processing Record 3 of Set 1 | sainte-thecle
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | mandalgovi
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | nikolskoye
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | salalah
# Processing Record 12 of Set 1 | geraldton
# Processing Record 13 of Set 1 | bandarban
# Processing Record 14 of Set 1 | margate
# Processing Record 15 of Set 1 | mehamn
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | fortuna
# Processing Record 18 of Set 1 | cayenne
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | lavrentiya
# Processing Record 21 of Set 1 | port elizabeth
# Processing Record 22 of Set 1 | paita
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | oktyabrskiy
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | saint-philippe
# Processing Record 28 of Set 1 | aklavik
# Processing Record 29 of Set 1 | rio grande
# Processing Record 30 of Set 1 | ostrovnoy
# Processing Record 31 of Set 1 | tuktoyaktuk
# Processing Record 32 of Set 1 | vredendal
# Processing Record 33 of Set 1 | belaya gora
# Processing Record 34 of Set 1 | thompson
# Processing Record 35 of Set 1 | hobyo
# Processing Record 36 of Set 1 | saskylakh
# Processing Record 37 of Set 1 | anchorage
# Processing Record 38 of Set 1 | norman wells
# Processing Record 39 of Set 1 | northam
# Processing Record 40 of Set 1 | cosala
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | fairbanks
# Processing Record 43 of Set 1 | hattiesburg
# Processing Record 44 of Set 1 | egvekinot
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | sistranda
# Processing Record 47 of Set 1 | chuy
# Processing Record 48 of Set 1 | butaritari
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | launceston
# Processing Record 1 of Set 2 | necochea
# Processing Record 2 of Set 2 | cap malheureux
# Processing Record 3 of Set 2 | avera
# Processing Record 4 of Set 2 | saquarema
# Processing Record 5 of Set 2 | yar-sale
# Processing Record 6 of Set 2 | maxixe
# Processing Record 7 of Set 2 | veraval
# Processing Record 8 of Set 2 | poum
# Processing Record 9 of Set 2 | iwade
# Processing Record 10 of Set 2 | ponta do sol
# Processing Record 11 of Set 2 | east london
# Processing Record 12 of Set 2 | wankaner
# Processing Record 13 of Set 2 | laplace
# Processing Record 14 of Set 2 | castro
# Processing Record 15 of Set 2 | qaanaaq
# Processing Record 16 of Set 2 | katsuura
# Processing Record 17 of Set 2 | nago
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | ituni
# City not found. Skipping...
# Processing Record 20 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 2 | misratah
# Processing Record 22 of Set 2 | vanimo
# Processing Record 23 of Set 2 | punta arenas
# Processing Record 24 of Set 2 | kyra
# Processing Record 25 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 26 of Set 2 | pevek
# Processing Record 27 of Set 2 | ieper
# Processing Record 28 of Set 2 | batagay
# Processing Record 29 of Set 2 | zhigansk
# Processing Record 30 of Set 2 | reconquista
# Processing Record 31 of Set 2 | chokurdakh
# Processing Record 32 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 2 | ahuimanu
# Processing Record 34 of Set 2 | port alfred
# Processing Record 35 of Set 2 | vaini
# Processing Record 36 of Set 2 | sur
# Processing Record 37 of Set 2 | torbay
# Processing Record 38 of Set 2 | isangel
# Processing Record 39 of Set 2 | sitka
# Processing Record 40 of Set 2 | kasongo-lunda
# Processing Record 41 of Set 2 | constitucion
# Processing Record 42 of Set 2 | ardakan
# Processing Record 43 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 2 | burkhala
# City not found. Skipping...
# Processing Record 45 of Set 2 | ossora
# Processing Record 46 of Set 2 | cidreira
# Processing Record 47 of Set 2 | zeya
# Processing Record 48 of Set 2 | airai
# Processing Record 49 of Set 2 | freeport
# Processing Record 50 of Set 2 | bathsheba
# Processing Record 1 of Set 3 | kamsack
# Processing Record 2 of Set 3 | bengkulu
# Processing Record 3 of Set 3 | port lincoln
# Processing Record 4 of Set 3 | oskemen
# Processing Record 5 of Set 3 | sao joao da barra
# Processing Record 6 of Set 3 | pontes e lacerda
# Processing Record 7 of Set 3 | victoria
# Processing Record 8 of Set 3 | dhidhdhoo
# Processing Record 9 of Set 3 | cabo san lucas
# Processing Record 10 of Set 3 | vostok
# Processing Record 11 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 3 | provideniya
# Processing Record 13 of Set 3 | ancud
# Processing Record 14 of Set 3 | clyde river
# Processing Record 15 of Set 3 | boa vista
# Processing Record 16 of Set 3 | dalby
# Processing Record 17 of Set 3 | dukat
# Processing Record 18 of Set 3 | yulara
# Processing Record 19 of Set 3 | yellowknife
# Processing Record 20 of Set 3 | progreso
# Processing Record 21 of Set 3 | bethel
# Processing Record 22 of Set 3 | vidim
# Processing Record 23 of Set 3 | waipawa
# Processing Record 24 of Set 3 | nemuro
# Processing Record 25 of Set 3 | khatanga
# Processing Record 26 of Set 3 | ribeira grande
# Processing Record 27 of Set 3 | wanaka
# Processing Record 28 of Set 3 | moses lake
# Processing Record 29 of Set 3 | amot
# Processing Record 30 of Set 3 | bredasdorp
# Processing Record 31 of Set 3 | letlhakeng
# Processing Record 32 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 3 | londa
# Processing Record 34 of Set 3 | souillac
# Processing Record 35 of Set 3 | koboldo
# City not found. Skipping...
# Processing Record 36 of Set 3 | tukrah
# Processing Record 37 of Set 3 | krasnovishersk
# Processing Record 38 of Set 3 | krasnogorskoye
# Processing Record 39 of Set 3 | pisco
# Processing Record 40 of Set 3 | buraydah
# Processing Record 41 of Set 3 | san policarpo
# Processing Record 42 of Set 3 | tasiilaq
# Processing Record 43 of Set 3 | pangnirtung
# Processing Record 44 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 3 | warka
# Processing Record 46 of Set 3 | vestmannaeyjar
# Processing Record 47 of Set 3 | boguchany
# Processing Record 48 of Set 3 | griffith
# Processing Record 49 of Set 3 | nantucket
# Processing Record 50 of Set 3 | khani
# Processing Record 1 of Set 4 | sobolevo
# Processing Record 2 of Set 4 | ahipara
# Processing Record 3 of Set 4 | sangar
# Processing Record 4 of Set 4 | noumea
# Processing Record 5 of Set 4 | kapoeta
# Processing Record 6 of Set 4 | new norfolk
# Processing Record 7 of Set 4 | rassvet
# Processing Record 8 of Set 4 | hilo
# Processing Record 9 of Set 4 | jamestown
# Processing Record 10 of Set 4 | tiksi
# Processing Record 11 of Set 4 | sibolga
# Processing Record 12 of Set 4 | nouadhibou
# Processing Record 13 of Set 4 | sao filipe
# Processing Record 14 of Set 4 | narsaq
# Processing Record 15 of Set 4 | namibe
# Processing Record 16 of Set 4 | maridi
# Processing Record 17 of Set 4 | pringsewu
# Processing Record 18 of Set 4 | port hardy
# Processing Record 19 of Set 4 | mbour
# Processing Record 20 of Set 4 | hay river
# Processing Record 21 of Set 4 | bambous virieux
# Processing Record 22 of Set 4 | ola
# Processing Record 23 of Set 4 | severo-kurilsk
# Processing Record 24 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 25 of Set 4 | luangwa
# Processing Record 26 of Set 4 | gushikawa
# Processing Record 27 of Set 4 | inhambane
# Processing Record 28 of Set 4 | charlestown
# Processing Record 29 of Set 4 | miri
# Processing Record 30 of Set 4 | wawa
# Processing Record 31 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 4 | haines junction
# Processing Record 33 of Set 4 | hays
# Processing Record 34 of Set 4 | rio gallegos
# Processing Record 35 of Set 4 | deputatskiy
# Processing Record 36 of Set 4 | khasan
# Processing Record 37 of Set 4 | port augusta
# Processing Record 38 of Set 4 | victoria point
# Processing Record 39 of Set 4 | mar del plata
# Processing Record 40 of Set 4 | north bend
# Processing Record 41 of Set 4 | vila velha
# Processing Record 42 of Set 4 | navahrudak
# Processing Record 43 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 4 | juegang
# Processing Record 45 of Set 4 | baoqing
# Processing Record 46 of Set 4 | san patricio
# Processing Record 47 of Set 4 | celestun
# Processing Record 48 of Set 4 | kindu
# Processing Record 49 of Set 4 | leskovac
# Processing Record 50 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 1 of Set 5 | carnarvon
# Processing Record 2 of Set 5 | magelang
# Processing Record 3 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 5 | gravdal
# Processing Record 5 of Set 5 | kahului
# Processing Record 6 of Set 5 | montepuez
# Processing Record 7 of Set 5 | saint-pierre
# Processing Record 8 of Set 5 | yeniseysk
# Processing Record 9 of Set 5 | muroto
# Processing Record 10 of Set 5 | la asuncion
# Processing Record 11 of Set 5 | trat
# Processing Record 12 of Set 5 | los llanos de aridane
# Processing Record 13 of Set 5 | longonjo
# Processing Record 14 of Set 5 | nuevo laredo
# Processing Record 15 of Set 5 | klaksvik
# Processing Record 16 of Set 5 | maraa
# Processing Record 17 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 5 | lebu
# Processing Record 19 of Set 5 | beringovskiy
# Processing Record 20 of Set 5 | avarua
# Processing Record 21 of Set 5 | bafilo
# Processing Record 22 of Set 5 | lompoc
# Processing Record 23 of Set 5 | dikson
# Processing Record 24 of Set 5 | saint-augustin
# Processing Record 25 of Set 5 | rovaniemi
# Processing Record 26 of Set 5 | shimoda
# Processing Record 27 of Set 5 | riyadh
# Processing Record 28 of Set 5 | georgetown
# Processing Record 29 of Set 5 | marica
# Processing Record 30 of Set 5 | elat
# Processing Record 31 of Set 5 | yunjinghong
# City not found. Skipping...
# Processing Record 32 of Set 5 | coihaique
# Processing Record 33 of Set 5 | vao
# Processing Record 34 of Set 5 | korla
# Processing Record 35 of Set 5 | ilulissat
# Processing Record 36 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 5 | concarneau
# Processing Record 38 of Set 5 | dawson
# Processing Record 39 of Set 5 | kerman
# Processing Record 40 of Set 5 | touros
# Processing Record 41 of Set 5 | brownsville
# Processing Record 42 of Set 5 | pitimbu
# Processing Record 43 of Set 5 | cherskiy
# Processing Record 44 of Set 5 | hualmay
# Processing Record 45 of Set 5 | fenoarivo
# Processing Record 46 of Set 5 | bengkalis
# City not found. Skipping...
# Processing Record 47 of Set 5 | port blair
# Processing Record 48 of Set 5 | mattru
# Processing Record 49 of Set 5 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 50 of Set 5 | evensk
# Processing Record 1 of Set 6 | kaitangata
# Processing Record 2 of Set 6 | takoradi
# Processing Record 3 of Set 6 | port shepstone
# Processing Record 4 of Set 6 | coquimbo
# Processing Record 5 of Set 6 | zhangye
# Processing Record 6 of Set 6 | nisia floresta
# Processing Record 7 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 6 | udachnyy
# Processing Record 9 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 6 | hof
# Processing Record 11 of Set 6 | sabang
# Processing Record 12 of Set 6 | caravelas
# Processing Record 13 of Set 6 | bumba
# Processing Record 14 of Set 6 | jardim
# Processing Record 15 of Set 6 | ashoknagar
# Processing Record 16 of Set 6 | marawi
# Processing Record 17 of Set 6 | qandala
# Processing Record 18 of Set 6 | ganzhou
# Processing Record 19 of Set 6 | dunmore east
# Processing Record 20 of Set 6 | concepcion
# Processing Record 21 of Set 6 | liverpool
# Processing Record 22 of Set 6 | mayumba
# Processing Record 23 of Set 6 | biltine
# Processing Record 24 of Set 6 | knyaze-volkonskoye
# Processing Record 25 of Set 6 | port hawkesbury
# Processing Record 26 of Set 6 | saint george
# Processing Record 27 of Set 6 | shelburne
# Processing Record 28 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 29 of Set 6 | kuna
# Processing Record 30 of Set 6 | cesme
# Processing Record 31 of Set 6 | chaochou
# City not found. Skipping...
# Processing Record 32 of Set 6 | porbandar
# Processing Record 33 of Set 6 | curvelo
# Processing Record 34 of Set 6 | tessaoua
# Processing Record 35 of Set 6 | brae
# Processing Record 36 of Set 6 | rumoi
# Processing Record 37 of Set 6 | katangli
# Processing Record 38 of Set 6 | tura
# Processing Record 39 of Set 6 | kirensk
# Processing Record 40 of Set 6 | dongsheng
# Processing Record 41 of Set 6 | laguna de perlas
# Processing Record 42 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 6 | trelew
# Processing Record 44 of Set 6 | upernavik
# Processing Record 45 of Set 6 | la ronge
# Processing Record 46 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 47 of Set 6 | bolgatanga
# Processing Record 48 of Set 6 | chino valley
# Processing Record 49 of Set 6 | guerrero negro
# Processing Record 50 of Set 6 | karratha
# Processing Record 1 of Set 7 | caramay
# Processing Record 2 of Set 7 | fort saint james
# Processing Record 3 of Set 7 | kruisfontein
# Processing Record 4 of Set 7 | naze
# Processing Record 5 of Set 7 | kamiiso
# Processing Record 6 of Set 7 | kamenka
# Processing Record 7 of Set 7 | oranjemund
# Processing Record 8 of Set 7 | angoche
# Processing Record 9 of Set 7 | severnyy
# Processing Record 10 of Set 7 | fredericksburg
# Processing Record 11 of Set 7 | achisay
# City not found. Skipping...
# Processing Record 12 of Set 7 | anadyr
# Processing Record 13 of Set 7 | quatre cocos
# Processing Record 14 of Set 7 | paucartambo
# City not found. Skipping...
# Processing Record 15 of Set 7 | hamilton
# Processing Record 16 of Set 7 | javanrud
# Processing Record 17 of Set 7 | ler
# Processing Record 18 of Set 7 | port-gentil
# Processing Record 19 of Set 7 | hithadhoo
# Processing Record 20 of Set 7 | novobirilyussy
# Processing Record 21 of Set 7 | katherine
# Processing Record 22 of Set 7 | berlevag
# Processing Record 23 of Set 7 | ketchikan
# Processing Record 24 of Set 7 | kyshtovka
# Processing Record 25 of Set 7 | svetlogorsk
# Processing Record 26 of Set 7 | vila franca do campo
# Processing Record 27 of Set 7 | strezhevoy
# Processing Record 28 of Set 7 | atar
# Processing Record 29 of Set 7 | malinovoye ozero
# Processing Record 30 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 31 of Set 7 | yagoua
# Processing Record 32 of Set 7 | piopio
# Processing Record 33 of Set 7 | sao francisco de assis
# Processing Record 34 of Set 7 | along
# Processing Record 35 of Set 7 | miraflores
# Processing Record 36 of Set 7 | mnogovershinnyy
# Processing Record 37 of Set 7 | safita
# Processing Record 38 of Set 7 | mehriz
# Processing Record 39 of Set 7 | severomorsk
# Processing Record 40 of Set 7 | shchelyayur
# City not found. Skipping...
# Processing Record 41 of Set 7 | nuevitas
# Processing Record 42 of Set 7 | sioux lookout
# Processing Record 43 of Set 7 | isla mujeres
# Processing Record 44 of Set 7 | luanda
# Processing Record 45 of Set 7 | zyryanka
# Processing Record 46 of Set 7 | jinchengjiang
# City not found. Skipping...
# Processing Record 47 of Set 7 | ipixuna
# Processing Record 48 of Set 7 | aswan
# Processing Record 49 of Set 7 | faya
# Processing Record 50 of Set 7 | imeni poliny osipenko
# Processing Record 1 of Set 8 | hun
# Processing Record 2 of Set 8 | hede
# Processing Record 3 of Set 8 | husavik
# Processing Record 4 of Set 8 | san jose
# Processing Record 5 of Set 8 | kajaani
# Processing Record 6 of Set 8 | milingimbi
# City not found. Skipping...
# Processing Record 7 of Set 8 | manakara
# Processing Record 8 of Set 8 | hami
# Processing Record 9 of Set 8 | road town
# Processing Record 10 of Set 8 | port said
# Processing Record 11 of Set 8 | mayya
# Processing Record 12 of Set 8 | college
# Processing Record 13 of Set 8 | kommunar
# Processing Record 14 of Set 8 | hanzhong
# Processing Record 15 of Set 8 | saldanha
# Processing Record 16 of Set 8 | muncar
# Processing Record 17 of Set 8 | tirur
# Processing Record 18 of Set 8 | tessalit
# Processing Record 19 of Set 8 | hailar
# Processing Record 20 of Set 8 | pekalongan
# Processing Record 21 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 22 of Set 8 | oda
# Processing Record 23 of Set 8 | cazaje
# City not found. Skipping...
# Processing Record 24 of Set 8 | puerto vallarta
# Processing Record 25 of Set 8 | simao
# Processing Record 26 of Set 8 | sola
# Processing Record 27 of Set 8 | olutanga
# Processing Record 28 of Set 8 | druzhba
# Processing Record 29 of Set 8 | laguna
# Processing Record 30 of Set 8 | lata
# Processing Record 31 of Set 8 | hovd
# Processing Record 32 of Set 8 | meitingen
# Processing Record 33 of Set 8 | platteville
# Processing Record 34 of Set 8 | galesong
# Processing Record 35 of Set 8 | adrar
# Processing Record 36 of Set 8 | san luis
# Processing Record 37 of Set 8 | goderich
# Processing Record 38 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 8 | diofior
# Processing Record 40 of Set 8 | sawtell
# Processing Record 41 of Set 8 | linxia
# Processing Record 42 of Set 8 | bababe
# City not found. Skipping...
# Processing Record 43 of Set 8 | barrhead
# Processing Record 44 of Set 8 | villazon
# Processing Record 45 of Set 8 | shingu
# Processing Record 46 of Set 8 | bernay
# Processing Record 47 of Set 8 | longyearbyen
# Processing Record 48 of Set 8 | porto walter
# Processing Record 49 of Set 8 | arraial do cabo
# Processing Record 50 of Set 8 | rincon
# Processing Record 1 of Set 9 | muzhi
# Processing Record 2 of Set 9 | juneau
# Processing Record 3 of Set 9 | kiruna
# Processing Record 4 of Set 9 | warrnambool
# Processing Record 5 of Set 9 | bisho
# Processing Record 6 of Set 9 | kiama
# Processing Record 7 of Set 9 | tual
# Processing Record 8 of Set 9 | mendi
# Processing Record 9 of Set 9 | christchurch
# Processing Record 10 of Set 9 | kovdor
# Processing Record 11 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 9 | biak
# Processing Record 13 of Set 9 | salinopolis
# Processing Record 14 of Set 9 | alexandria
# Processing Record 15 of Set 9 | tuatapere
# Processing Record 16 of Set 9 | grand gaube
# Processing Record 17 of Set 9 | kudahuvadhoo
# Processing Record 18 of Set 9 | pecos
# Processing Record 19 of Set 9 | gasa
# Processing Record 20 of Set 9 | cockburn town
# Processing Record 21 of Set 9 | morlaix
# Processing Record 22 of Set 9 | tautira
# Processing Record 23 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 9 | alofi
# Processing Record 25 of Set 9 | iisalmi
# Processing Record 26 of Set 9 | kuala sungai baru
# Processing Record 27 of Set 9 | taunggyi
# Processing Record 28 of Set 9 | dafeng
# Processing Record 29 of Set 9 | barrow
# Processing Record 30 of Set 9 | kumano
# Processing Record 31 of Set 9 | buchanan
# Processing Record 32 of Set 9 | erenhot
# Processing Record 33 of Set 9 | bubaque
# Processing Record 34 of Set 9 | mayo
# Processing Record 35 of Set 9 | winnemucca
# Processing Record 36 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 37 of Set 9 | aksu
# Processing Record 38 of Set 9 | kupang
# Processing Record 39 of Set 9 | mantua
# Processing Record 40 of Set 9 | alice springs
# Processing Record 41 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 42 of Set 9 | codrington
# Processing Record 43 of Set 9 | mahebourg
# Processing Record 44 of Set 9 | yetholm
# City not found. Skipping...
# Processing Record 45 of Set 9 | labuhan
# Processing Record 46 of Set 9 | kawalu
# Processing Record 47 of Set 9 | omboue
# Processing Record 48 of Set 9 | rawson
# Processing Record 49 of Set 9 | kampong thum
# Processing Record 50 of Set 9 | nauta
# Processing Record 1 of Set 10 | dakar
# Processing Record 2 of Set 10 | yeppoon
# Processing Record 3 of Set 10 | vardo
# Processing Record 4 of Set 10 | belyy yar
# Processing Record 5 of Set 10 | jacobabad
# Processing Record 6 of Set 10 | esperance
# Processing Record 7 of Set 10 | portland
# Processing Record 8 of Set 10 | berdigestyakh
# Processing Record 9 of Set 10 | ambanja
# Processing Record 10 of Set 10 | plouzane
# Processing Record 11 of Set 10 | buala
# Processing Record 12 of Set 10 | gisborne
# Processing Record 13 of Set 10 | raton
# Processing Record 14 of Set 10 | ayagoz
# Processing Record 15 of Set 10 | cedar city
# Processing Record 16 of Set 10 | chicama
# Processing Record 17 of Set 10 | xiangdong
# City not found. Skipping...
# Processing Record 18 of Set 10 | hammerfest
# Processing Record 19 of Set 10 | gap
# Processing Record 20 of Set 10 | dingle
# Processing Record 21 of Set 10 | sofiysk
# City not found. Skipping...
# Processing Record 22 of Set 10 | burica
# City not found. Skipping...
# Processing Record 23 of Set 10 | kavaratti
# Processing Record 24 of Set 10 | lewistown
# Processing Record 25 of Set 10 | umarkhed
# Processing Record 26 of Set 10 | ngunguru
# Processing Record 27 of Set 10 | azrow
# City not found. Skipping...
# Processing Record 28 of Set 10 | waingapu
# Processing Record 29 of Set 10 | havoysund
# Processing Record 30 of Set 10 | monrovia
# Processing Record 31 of Set 10 | muros
# Processing Record 32 of Set 10 | hokitika
# Processing Record 33 of Set 10 | mocuba
# Processing Record 34 of Set 10 | saurimo
# Processing Record 35 of Set 10 | muravlenko
# Processing Record 36 of Set 10 | wamba
# Processing Record 37 of Set 10 | nikel
# Processing Record 38 of Set 10 | nam tha
# City not found. Skipping...
# Processing Record 39 of Set 10 | san pedro
# Processing Record 40 of Set 10 | nekhayevskiy
# Processing Record 41 of Set 10 | nome
# Processing Record 42 of Set 10 | flinders
# Processing Record 43 of Set 10 | namwala
# Processing Record 44 of Set 10 | luderitz
# Processing Record 45 of Set 10 | maunabo
# Processing Record 46 of Set 10 | goiatuba
# Processing Record 47 of Set 10 | kenai
# Processing Record 48 of Set 10 | nanortalik
# Processing Record 49 of Set 10 | leghorn
# City not found. Skipping...
# Processing Record 50 of Set 10 | kolpashevo
# Processing Record 1 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 2 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 11 | tostamaa
# City not found. Skipping...
# Processing Record 4 of Set 11 | buluang
# Processing Record 5 of Set 11 | port hedland
# Processing Record 6 of Set 11 | mujiayingzi
# Processing Record 7 of Set 11 | buzmeyin
# Processing Record 8 of Set 11 | manono
# Processing Record 9 of Set 11 | tutora
# Processing Record 10 of Set 11 | cape coast
# Processing Record 11 of Set 11 | pacific grove
# Processing Record 12 of Set 11 | chitipa
# Processing Record 13 of Set 11 | mangit
# Processing Record 14 of Set 11 | paamiut
# Processing Record 15 of Set 11 | jalu
# Processing Record 16 of Set 11 | asau
# Processing Record 17 of Set 11 | beloha
# Processing Record 18 of Set 11 | ucluelet
# Processing Record 19 of Set 11 | inirida
# Processing Record 20 of Set 11 | magistralnyy
# Processing Record 21 of Set 11 | leshukonskoye
# Processing Record 22 of Set 11 | douentza
# Processing Record 23 of Set 11 | athabasca
# Processing Record 24 of Set 11 | kununurra
# Processing Record 25 of Set 11 | burnie
# Processing Record 26 of Set 11 | scarborough
# Processing Record 27 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 11 | mlonggo
# Processing Record 29 of Set 11 | le port
# Processing Record 30 of Set 11 | picos
# Processing Record 31 of Set 11 | kawana waters
# City not found. Skipping...
# Processing Record 32 of Set 11 | cotonou
# Processing Record 33 of Set 11 | verkhoyansk
# Processing Record 34 of Set 11 | khvalynsk
# Processing Record 35 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 36 of Set 11 | rabak
# Processing Record 37 of Set 11 | ledyard
# Processing Record 38 of Set 11 | kavieng
# Processing Record 39 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 11 | mount gambier
# Processing Record 41 of Set 11 | adelaide
# Processing Record 42 of Set 11 | kaoma
# Processing Record 43 of Set 11 | kandrian
# Processing Record 44 of Set 11 | illapel
# Processing Record 45 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 46 of Set 11 | mago
# Processing Record 47 of Set 11 | nakapiripirit
# Processing Record 48 of Set 11 | linkou
# Processing Record 49 of Set 11 | mbuji-mayi
# Processing Record 50 of Set 11 | suoyarvi
# Processing Record 1 of Set 12 | nokaneng
# Processing Record 2 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 3 of Set 12 | antofagasta
# Processing Record 4 of Set 12 | vanavara
# Processing Record 5 of Set 12 | santa fe
# Processing Record 6 of Set 12 | padang
# Processing Record 7 of Set 12 | krieglach
# Processing Record 8 of Set 12 | yaan
# Processing Record 9 of Set 12 | hervey bay
# Processing Record 10 of Set 12 | saint-joseph
# Processing Record 11 of Set 12 | karasjok
# Processing Record 12 of Set 12 | sakaiminato
# Processing Record 13 of Set 12 | limon
# Processing Record 14 of Set 12 | ambilobe
# Processing Record 15 of Set 12 | bafata
# Processing Record 16 of Set 12 | kieta
# Processing Record 17 of Set 12 | mackay
# Processing Record 18 of Set 12 | zuwarah
# Processing Record 19 of Set 12 | flin flon
# Processing Record 20 of Set 12 | comodoro rivadavia
# Processing Record 21 of Set 12 | robertsport
# Processing Record 22 of Set 12 | taltal
# Processing Record 23 of Set 12 | uyemskiy
# Processing Record 24 of Set 12 | nuevo progreso
# Processing Record 25 of Set 12 | andahuaylas
# Processing Record 26 of Set 12 | pogar
# Processing Record 27 of Set 12 | birao
# Processing Record 28 of Set 12 | bezhanitsy
# Processing Record 29 of Set 12 | hofn
# Processing Record 30 of Set 12 | beira
# Processing Record 31 of Set 12 | togur
# Processing Record 32 of Set 12 | ayautla
# City not found. Skipping...
# Processing Record 33 of Set 12 | parainen
# Processing Record 34 of Set 12 | cookeville
# Processing Record 35 of Set 12 | tuskegee
# Processing Record 36 of Set 12 | atchison
# Processing Record 37 of Set 12 | huarmey
# Processing Record 38 of Set 12 | granja
# Processing Record 39 of Set 12 | lorengau
# Processing Record 40 of Set 12 | pilibhit
# Processing Record 41 of Set 12 | gashua
# Processing Record 42 of Set 12 | autazes
# Processing Record 43 of Set 12 | zhezkazgan
# Processing Record 44 of Set 12 | neiafu
# Processing Record 45 of Set 12 | kibala
# Processing Record 46 of Set 12 | nuuk
# Processing Record 47 of Set 12 | adre
# Processing Record 48 of Set 12 | tunduru
# City not found. Skipping...
# Processing Record 49 of Set 12 | te anau
# Processing Record 50 of Set 12 | filadelfia
# Processing Record 1 of Set 13 | lang son
# Processing Record 2 of Set 13 | stokmarknes
# Processing Record 3 of Set 13 | lannion
# Processing Record 4 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 5 of Set 13 | igarka
# Processing Record 6 of Set 13 | acarau
# Processing Record 7 of Set 13 | horsham
# Processing Record 8 of Set 13 | tomigusuku
# Processing Record 9 of Set 13 | bonavista
# Processing Record 10 of Set 13 | maniitsoq
# Processing Record 11 of Set 13 | buckeye
# Processing Record 12 of Set 13 | vestmanna
# Processing Record 13 of Set 13 | abu zabad
# Processing Record 14 of Set 13 | carahue
# Processing Record 15 of Set 13 | kota bahru
# Processing Record 16 of Set 13 | bilma
# Processing Record 17 of Set 13 | kirovskiy
# Processing Record 18 of Set 13 | general pico
# Processing Record 19 of Set 13 | coahuayana
# Processing Record 20 of Set 13 | la grande
# Processing Record 21 of Set 13 | dongargaon
# Processing Record 22 of Set 13 | paciran
# Processing Record 23 of Set 13 | daphne
# Processing Record 24 of Set 13 | morehead
# Processing Record 25 of Set 13 | dergachi
# Processing Record 26 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 27 of Set 13 | chlumec
# Processing Record 28 of Set 13 | hasaki
# Processing Record 29 of Set 13 | marly
# Processing Record 30 of Set 13 | itaqui
# Processing Record 31 of Set 13 | limbe
# Processing Record 32 of Set 13 | san isidro
# Processing Record 33 of Set 13 | puerto del rosario
# Processing Record 34 of Set 13 | sovetskiy
# Processing Record 35 of Set 13 | cubuk
# Processing Record 36 of Set 13 | mazamet
# Processing Record 37 of Set 13 | chengam
# Processing Record 38 of Set 13 | tawang
# Processing Record 39 of Set 13 | tibati
# Processing Record 40 of Set 13 | tunghsiao
# City not found. Skipping...
# Processing Record 41 of Set 13 | leningradskiy
# Processing Record 42 of Set 13 | glubokiy
# Processing Record 43 of Set 13 | leiyang
# Processing Record 44 of Set 13 | lima
# Processing Record 45 of Set 13 | troitsko-pechorsk
# Processing Record 46 of Set 13 | ayan
# Processing Record 47 of Set 13 | matagami
# Processing Record 48 of Set 13 | rabo de peixe
# Processing Record 49 of Set 13 | neuquen
# Processing Record 50 of Set 13 | dzerzhinskoye
# Processing Record 1 of Set 14 | palmer
# Processing Record 2 of Set 14 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 3 of Set 14 | aksarka
# Processing Record 4 of Set 14 | bow island
# Processing Record 5 of Set 14 | sao felix do xingu
# Processing Record 6 of Set 14 | grindavik
# Processing Record 7 of Set 14 | gaogou
# Processing Record 8 of Set 14 | pedernales
# Processing Record 9 of Set 14 | samarinda
# Processing Record 10 of Set 14 | walvis bay
# Processing Record 11 of Set 14 | saint-raymond
# Processing Record 12 of Set 14 | verkhoturye
# Processing Record 13 of Set 14 | xingyi
# Processing Record 14 of Set 14 | voroshnevo
# Processing Record 15 of Set 14 | vigrestad
# Processing Record 16 of Set 14 | san cristobal
# Processing Record 17 of Set 14 | carman
# Processing Record 18 of Set 14 | warangal
# Processing Record 19 of Set 14 | banyuwangi
# Processing Record 20 of Set 14 | loreto
# Processing Record 21 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 22 of Set 14 | son la
# Processing Record 23 of Set 14 | vaitape
# Processing Record 24 of Set 14 | eyl
# Processing Record 25 of Set 14 | pimentel
# Processing Record 26 of Set 14 | itoman
# Processing Record 27 of Set 14 | trofaiach
# Processing Record 28 of Set 14 | badvel
# Processing Record 29 of Set 14 | namatanai
# Processing Record 30 of Set 14 | pucallpa
# Processing Record 31 of Set 14 | healdsburg
# Processing Record 32 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 14 | naica
# Processing Record 34 of Set 14 | waharoa
# Processing Record 35 of Set 14 | almaznyy
# Processing Record 36 of Set 14 | alta floresta
# Processing Record 37 of Set 14 | trincomalee
# Processing Record 38 of Set 14 | quelimane
# Processing Record 39 of Set 14 | anzhero-sudzhensk
# Processing Record 40 of Set 14 | axim
# Processing Record 41 of Set 14 | qasigiannguit
# Processing Record 42 of Set 14 | datong
# Processing Record 43 of Set 14 | kokopo
# Processing Record 44 of Set 14 | varberg
# Processing Record 45 of Set 14 | panama city
# Processing Record 46 of Set 14 | san andres
# Processing Record 47 of Set 14 | vega de alatorre
# Processing Record 48 of Set 14 | mani
# Processing Record 49 of Set 14 | ulundi
# Processing Record 50 of Set 14 | suileng
# Processing Record 1 of Set 15 | tefe
# Processing Record 2 of Set 15 | oktyabrskoye
# Processing Record 3 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 15 | mount isa
# Processing Record 5 of Set 15 | catemaco
# Processing Record 6 of Set 15 | rio de jesus
# Processing Record 7 of Set 15 | lebowakgomo
# Processing Record 8 of Set 15 | mariinskiy posad
# Processing Record 9 of Set 15 | sungurlu
# Processing Record 10 of Set 15 | nelson bay
# Processing Record 11 of Set 15 | newport
# Processing Record 12 of Set 15 | gamba
# Processing Record 13 of Set 15 | talnakh
# Processing Record 14 of Set 15 | kirillov
# Processing Record 15 of Set 15 | rawah
# Processing Record 16 of Set 15 | voh
# Processing Record 17 of Set 15 | rawlins
# Processing Record 18 of Set 15 | srednekolymsk
# Processing Record 19 of Set 15 | morondava
# Processing Record 20 of Set 15 | port macquarie
# Processing Record 21 of Set 15 | haimen
# Processing Record 22 of Set 15 | pierre
# Processing Record 23 of Set 15 | baykit
# Processing Record 24 of Set 15 | marechal deodoro
# Processing Record 25 of Set 15 | allada
# Processing Record 26 of Set 15 | urumqi
# Processing Record 27 of Set 15 | honningsvag
# Processing Record 28 of Set 15 | gimli
# Processing Record 29 of Set 15 | amazar
# Processing Record 30 of Set 15 | nelidovo
# Processing Record 31 of Set 15 | rosarito
# Processing Record 32 of Set 15 | henties bay
# Processing Record 33 of Set 15 | phun phin
# City not found. Skipping...
# Processing Record 34 of Set 15 | great falls
# Processing Record 35 of Set 15 | okhotsk
# Processing Record 36 of Set 15 | fereydunshahr
# Processing Record 37 of Set 15 | iqaluit
# Processing Record 38 of Set 15 | sultanpur
# Processing Record 39 of Set 15 | salamiyah
# Processing Record 40 of Set 15 | staraya vichuga
# Processing Record 41 of Set 15 | whitianga
# Processing Record 42 of Set 15 | nador
# Processing Record 43 of Set 15 | bandarbeyla
# Processing Record 44 of Set 15 | barra do garcas
# Processing Record 45 of Set 15 | kuminskiy
# Processing Record 46 of Set 15 | santander
# Processing Record 47 of Set 15 | mehran
# Processing Record 48 of Set 15 | miles city
# Processing Record 49 of Set 15 | udalguri
# Processing Record 50 of Set 15 | kilosa
# Processing Record 1 of Set 16 | mahibadhoo
# Processing Record 2 of Set 16 | laizhou
# Processing Record 3 of Set 16 | morgan city
# Processing Record 4 of Set 16 | acireale
# Processing Record 5 of Set 16 | gillette
# Processing Record 6 of Set 16 | fort saint john
# City not found. Skipping...
# Processing Record 7 of Set 16 | smolenka
# Processing Record 8 of Set 16 | umm jarr
# City not found. Skipping...
# Processing Record 9 of Set 16 | banda aceh
# Processing Record 10 of Set 16 | nabire
# Processing Record 11 of Set 16 | saint-francois
# Processing Record 12 of Set 16 | kapit
# Processing Record 13 of Set 16 | oparino
# Processing Record 14 of Set 16 | moose factory
# Processing Record 15 of Set 16 | belmonte
# Processing Record 16 of Set 16 | tarboro
# Processing Record 17 of Set 16 | ahumada
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description" ]
city_data_df = pd.DataFrame(city_data)
city_data_df = city_data_df[column_order]
city_data_df.head()
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Camacha      PT  33.0833  -16.3333     71.53        78          75
# 1         Faanui      PF -16.4833 -151.7500     78.78        75          55
# 2  Sainte-Thecle      CA  46.8168  -72.4991     77.05        76         100
# 3         Hobart      AU -42.8794  147.3294     50.25        88          75
# 4     Mandalgovi      MN  45.7625  106.2708     62.80        67          79
#
#    Wind Speed Current Description
# 0       11.50       broken clouds
# 1       12.50       broken clouds
# 2        6.78     overcast clouds
# 3        1.01       broken clouds
# 4        4.50       broken clouds

# %%
output_weather_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_weather_file, index_label="City_ID")
